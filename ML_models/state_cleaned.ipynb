# %%
import pandas as pd

# %%
# Import the possible data
states_df = pd.read_csv("../Resources/states.ts.csv")
states_df
# Out:
#           date country state  county  fips  lat  long          locationId  \
# 0       3/1/20      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 1       3/2/20      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 2       3/3/20      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 3       3/4/20      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 4       3/5/20      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# ...        ...     ...   ...     ...   ...  ...   ...                 ...
# 56833  1/30/23      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 56834  1/31/23      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 56835   2/1/23      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 56836   2/2/23      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 56837   2/3/23      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
#
#        actuals.cases  actuals.deaths  ...  \
# 0                NaN             NaN  ...
# 1                NaN             NaN  ...
# 2                NaN             NaN  ...
# 3                NaN             NaN  ...
# 4                NaN             NaN  ...
# ...              ...             ...  ...
# 56833       183774.0          1978.0  ...
# 56834       183173.0          1980.0  ...
# 56835       183173.0          1980.0  ...
# 56836       183173.0          1980.0  ...
# 56837       183173.0          1980.0  ...
#
#        actuals.hsaHospitalBeds.currentUsageCovid  actuals.hsaIcuBeds.capacity  \
# 0                                            NaN                          NaN
# 1                                            NaN                          NaN
# 2                                            NaN                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# ...                                          ...                          ...
# 56833                                        NaN                          NaN
# 56834                                        NaN                          NaN
# 56835                                        NaN                          NaN
# 56836                                        NaN                          NaN
# 56837                                        NaN                          NaN
#
#        actuals.hsaIcuBeds.currentUsageTotal  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 56833                                   NaN
# 56834                                   NaN
# 56835                                   NaN
# 56836                                   NaN
# 56837                                   NaN
#
#        actuals.hsaIcuBeds.currentUsageCovid  hsaName  \
# 0                                       NaN      NaN
# 1                                       NaN      NaN
# 2                                       NaN      NaN
# 3                                       NaN      NaN
# 4                                       NaN      NaN
# ...                                     ...      ...
# 56833                                   NaN      NaN
# 56834                                   NaN      NaN
# 56835                                   NaN      NaN
# 56836                                   NaN      NaN
# 56837                                   NaN      NaN
#
#        actuals.hospitalBeds.weeklyCovidAdmissions  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 56833                                        17.0
# 56834                                        19.0
# 56835                                        20.0
# 56836                                        21.0
# 56837                                        21.0
#
#        actuals.hsaHospitalBeds.weeklyCovidAdmissions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 56833                                            NaN
# 56834                                            NaN
# 56835                                            NaN
# 56836                                            NaN
# 56837                                            NaN
#
#        communityLevels.cdcCommunityLevel  communityLevels.canCommunityLevel  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ...                                  ...                                ...
# 56833                                NaN                                0.0
# 56834                                NaN                                0.0
# 56835                                NaN                                0.0
# 56836                                NaN                                0.0
# 56837                                NaN                                0.0
#
#        actuals.vaccinationsFall2022BivalentBooster
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 56833                                          NaN
# 56834                                          NaN
# 56835                                      61321.0
# 56836                                          NaN
# 56837                                          NaN
#
# [56838 rows x 43 columns]

# %%
# Get the data types
pd.set_option('display.max_rows', 70)
states_df.dtypes
# Out:
# date                                              object
# country                                           object
# state                                             object
# county                                           float64
# fips                                               int64
# lat                                              float64
# long                                             float64
# locationId                                        object
# actuals.cases                                    float64
# actuals.deaths                                   float64
# actuals.positiveTests                            float64
# actuals.negativeTests                            float64
# actuals.contactTracers                           float64
# actuals.hospitalBeds.capacity                    float64
# actuals.hospitalBeds.currentUsageTotal           float64
# actuals.hospitalBeds.currentUsageCovid           float64
# actuals.icuBeds.capacity                         float64
# actuals.icuBeds.currentUsageTotal                float64
# actuals.icuBeds.currentUsageCovid                float64
# actuals.newCases                                 float64
# actuals.vaccinesDistributed                      float64
# actuals.vaccinationsInitiated                    float64
# actuals.vaccinationsCompleted                    float64
# riskLevels.overall                                 int64
# actuals.newDeaths                                float64
# actuals.vaccinesAdministered                     float64
# riskLevels.caseDensity                             int64
# cdcTransmissionLevel                               int64
# actuals.vaccinationsAdditionalDose               float64
# hsa                                              float64
# hsaPopulation                                    float64
# actuals.hsaHospitalBeds.capacity                 float64
# actuals.hsaHospitalBeds.currentUsageTotal        float64
# actuals.hsaHospitalBeds.currentUsageCovid        float64
# actuals.hsaIcuBeds.capacity                      float64
# actuals.hsaIcuBeds.currentUsageTotal             float64
# actuals.hsaIcuBeds.currentUsageCovid             float64
# hsaName                                          float64
# actuals.hospitalBeds.weeklyCovidAdmissions       float64
# actuals.hsaHospitalBeds.weeklyCovidAdmissions    float64
# communityLevels.cdcCommunityLevel                float64
# communityLevels.canCommunityLevel                float64
# actuals.vaccinationsFall2022BivalentBooster      float64
# dtype: object

# %%
# Get the length of each column
states_df.count()
# Out:
# date                                             56838
# country                                          56838
# state                                            56838
# county                                               0
# fips                                             56838
# lat                                                  0
# long                                                 0
# locationId                                       56838
# actuals.cases                                    56561
# actuals.deaths                                   56640
# actuals.positiveTests                            55226
# actuals.negativeTests                            55464
# actuals.contactTracers                           31391
# actuals.hospitalBeds.capacity                    45633
# actuals.hospitalBeds.currentUsageTotal           45633
# actuals.hospitalBeds.currentUsageCovid           45633
# actuals.icuBeds.capacity                         45633
# actuals.icuBeds.currentUsageTotal                45633
# actuals.icuBeds.currentUsageCovid                45633
# actuals.newCases                                 56231
# actuals.vaccinesDistributed                      28544
# actuals.vaccinationsInitiated                    28771
# actuals.vaccinationsCompleted                    28771
# riskLevels.overall                               56838
# actuals.newDeaths                                56217
# actuals.vaccinesAdministered                     28544
# riskLevels.caseDensity                           56838
# cdcTransmissionLevel                             56838
# actuals.vaccinationsAdditionalDose               16423
# hsa                                                  0
# hsaPopulation                                     1070
# actuals.hsaHospitalBeds.capacity                     0
# actuals.hsaHospitalBeds.currentUsageTotal            0
# actuals.hsaHospitalBeds.currentUsageCovid            0
# actuals.hsaIcuBeds.capacity                          0
# actuals.hsaIcuBeds.currentUsageTotal                 0
# actuals.hsaIcuBeds.currentUsageCovid                 0
# hsaName                                              0
# actuals.hospitalBeds.weeklyCovidAdmissions       45315
# actuals.hsaHospitalBeds.weeklyCovidAdmissions        0
# communityLevels.cdcCommunityLevel                    0
# communityLevels.canCommunityLevel                45635
# actuals.vaccinationsFall2022BivalentBooster        784
# dtype: int64

# %%
columns_to_drop = ['county', 'lat', 'long', 'hsa', 'hsaPopulation', 'actuals.hsaHospitalBeds.capacity', 
                   'actuals.hsaHospitalBeds.currentUsageTotal', 'actuals.hsaHospitalBeds.currentUsageCovid', 
                   'actuals.hsaIcuBeds.capacity', 'actuals.hsaIcuBeds.currentUsageTotal', 
                   'actuals.hsaIcuBeds.currentUsageCovid', 'hsaName', 
                   'actuals.hsaHospitalBeds.weeklyCovidAdmissions', 
                   'communityLevels.cdcCommunityLevel', 'actuals.vaccinationsFall2022BivalentBooster']

# %%
# Drop the columns
states_dropped = states_df.drop(columns_to_drop, axis=1)
states_dropped
# Out:
#           date country state  fips          locationId  actuals.cases  \
# 0       3/1/20      US    AK     2  iso1:us#iso2:us-ak            NaN
# 1       3/2/20      US    AK     2  iso1:us#iso2:us-ak            NaN
# 2       3/3/20      US    AK     2  iso1:us#iso2:us-ak            NaN
# 3       3/4/20      US    AK     2  iso1:us#iso2:us-ak            NaN
# 4       3/5/20      US    AK     2  iso1:us#iso2:us-ak            NaN
# ...        ...     ...   ...   ...                 ...            ...
# 56833  1/30/23      US    WY    56  iso1:us#iso2:us-wy       183774.0
# 56834  1/31/23      US    WY    56  iso1:us#iso2:us-wy       183173.0
# 56835   2/1/23      US    WY    56  iso1:us#iso2:us-wy       183173.0
# 56836   2/2/23      US    WY    56  iso1:us#iso2:us-wy       183173.0
# 56837   2/3/23      US    WY    56  iso1:us#iso2:us-wy       183173.0
#
#        actuals.deaths  actuals.positiveTests  actuals.negativeTests  \
# 0                 NaN                    NaN                    4.0
# 1                 NaN                    NaN                    4.0
# 2                 NaN                    NaN                    6.0
# 3                 NaN                    NaN                   18.0
# 4                 NaN                    NaN                   27.0
# ...               ...                    ...                    ...
# 56833          1978.0               136311.0              1423202.0
# 56834          1980.0               136314.0              1423243.0
# 56835          1980.0                    NaN                    NaN
# 56836          1980.0                    NaN                    NaN
# 56837          1980.0                    NaN                    NaN
#
#        actuals.contactTracers  ...  actuals.vaccinationsInitiated  \
# 0                         NaN  ...                            NaN
# 1                         NaN  ...                            NaN
# 2                         NaN  ...                            NaN
# 3                         NaN  ...                            NaN
# 4                         NaN  ...                            NaN
# ...                       ...  ...                            ...
# 56833                     NaN  ...                            NaN
# 56834                     NaN  ...                            NaN
# 56835                     NaN  ...                       352104.0
# 56836                     NaN  ...                            NaN
# 56837                     NaN  ...                            NaN
#
#        actuals.vaccinationsCompleted  riskLevels.overall  actuals.newDeaths  \
# 0                                NaN                   0                NaN
# 1                                NaN                   0                NaN
# 2                                NaN                   0                NaN
# 3                                NaN                   0                NaN
# 4                                NaN                   0                NaN
# ...                              ...                 ...                ...
# 56833                            NaN                   1                0.0
# 56834                            NaN                   1                2.0
# 56835                       306661.0                   1                0.0
# 56836                            NaN                   1                0.0
# 56837                            NaN                   1                0.0
#
#        actuals.vaccinesAdministered  riskLevels.caseDensity  \
# 0                               NaN                       0
# 1                               NaN                       0
# 2                               NaN                       0
# 3                               NaN                       0
# 4                               NaN                       0
# ...                             ...                     ...
# 56833                           NaN                       1
# 56834                           NaN                       1
# 56835                      847573.0                       1
# 56836                           NaN                       1
# 56837                           NaN                       1
#
#        cdcTransmissionLevel  actuals.vaccinationsAdditionalDose  \
# 0                         0                                 NaN
# 1                         0                                 NaN
# 2                         0                                 NaN
# 3                         0                                 NaN
# 4                         0                                 NaN
# ...                     ...                                 ...
# 56833                     2                                 NaN
# 56834                     2                                 NaN
# 56835                     2                            144559.0
# 56836                     2                                 NaN
# 56837                     2                                 NaN
#
#        actuals.hospitalBeds.weeklyCovidAdmissions  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 56833                                        17.0
# 56834                                        19.0
# 56835                                        20.0
# 56836                                        21.0
# 56837                                        21.0
#
#        communityLevels.canCommunityLevel
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 56833                                0.0
# 56834                                0.0
# 56835                                0.0
# 56836                                0.0
# 56837                                0.0
#
# [56838 rows x 28 columns]

# %%
# Verify count()
states_dropped.count()
# Out:
# date                                          56838
# country                                       56838
# state                                         56838
# fips                                          56838
# locationId                                    56838
# actuals.cases                                 56561
# actuals.deaths                                56640
# actuals.positiveTests                         55226
# actuals.negativeTests                         55464
# actuals.contactTracers                        31391
# actuals.hospitalBeds.capacity                 45633
# actuals.hospitalBeds.currentUsageTotal        45633
# actuals.hospitalBeds.currentUsageCovid        45633
# actuals.icuBeds.capacity                      45633
# actuals.icuBeds.currentUsageTotal             45633
# actuals.icuBeds.currentUsageCovid             45633
# actuals.newCases                              56231
# actuals.vaccinesDistributed                   28544
# actuals.vaccinationsInitiated                 28771
# actuals.vaccinationsCompleted                 28771
# riskLevels.overall                            56838
# actuals.newDeaths                             56217
# actuals.vaccinesAdministered                  28544
# riskLevels.caseDensity                        56838
# cdcTransmissionLevel                          56838
# actuals.vaccinationsAdditionalDose            16423
# actuals.hospitalBeds.weeklyCovidAdmissions    45315
# communityLevels.canCommunityLevel             45635
# dtype: int64

# %%
# Drop any null values
states_cleaned = states_dropped.dropna()

# %%
# Verify length of cleaned data
states_cleaned.count()
# Out:
# date                                          6637
# country                                       6637
# state                                         6637
# fips                                          6637
# locationId                                    6637
# actuals.cases                                 6637
# actuals.deaths                                6637
# actuals.positiveTests                         6637
# actuals.negativeTests                         6637
# actuals.contactTracers                        6637
# actuals.hospitalBeds.capacity                 6637
# actuals.hospitalBeds.currentUsageTotal        6637
# actuals.hospitalBeds.currentUsageCovid        6637
# actuals.icuBeds.capacity                      6637
# actuals.icuBeds.currentUsageTotal             6637
# actuals.icuBeds.currentUsageCovid             6637
# actuals.newCases                              6637
# actuals.vaccinesDistributed                   6637
# actuals.vaccinationsInitiated                 6637
# actuals.vaccinationsCompleted                 6637
# riskLevels.overall                            6637
# actuals.newDeaths                             6637
# actuals.vaccinesAdministered                  6637
# riskLevels.caseDensity                        6637
# cdcTransmissionLevel                          6637
# actuals.vaccinationsAdditionalDose            6637
# actuals.hospitalBeds.weeklyCovidAdmissions    6637
# communityLevels.canCommunityLevel             6637
# dtype: int64

# %%
# Save the new csv
states_cleaned.csv("states.csv", sep=',', header=True, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/m8/kwpm86r17gj0c5qnwcc3b9nm0000gn/T/ipykernel_16206/3738634264.py in <module>
#       1 # Save the new csv
# ----> 2 statesto_csv("states_no_metrics.csv", sep=',', header=True, encoding='utf-8')
#
# NameError: name 'statesto_csv' is not defined
